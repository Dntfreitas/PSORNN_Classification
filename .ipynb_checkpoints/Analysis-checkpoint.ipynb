# %%
import pandas as pd
import numpy as np
import re
import glob, os
from IPython.display import display, Markdown, Latex

# %%
db_names = ['parkinsons', 'car', 'red_wine', 'white_wine']

pd_results = pd.DataFrame([])

for db_name in db_names:
    for file in glob.glob("*.csv"):
        if db_name in file:
            pd_results_aux = pd.read_csv(file)
            pd_results_aux['Database'] = db_name
            feature_algorithm = re.split('-|_', file)
            if feature_algorithm[1] == 'hybrid':
                pd_results_aux['OptimizationAlgorithm'] = feature_algorithm[0]+'-'+'Hybrid'
            else:
                pd_results_aux['OptimizationAlgorithm'] = feature_algorithm[0]
            pd_results_aux['FeatureSelectionMethod'] = feature_algorithm[-1].split('.')[0]
            pd_results_aux['OptimizationFeature'] = pd_results_aux['OptimizationAlgorithm'] + '-' + pd_results_aux['FeatureSelectionMethod'] 
            pd_results = pd_results.append(pd_results_aux)

# %%
pd_results.groupby(by=['OptimizationFeature','No. hidden']).max()
# Out:
#                                  Best Acc  Worst Acc       Mean        STD  \
# OptimizationFeature No. hidden
# LMA-CHI2            4           82.758621  71.042471  74.137931   5.204244
#                     7           89.655172  72.200772  75.172414   8.415175
#                     10          89.655172  71.042471  75.517241   6.592934
#                     12          89.655172  72.586873  73.359073  13.350168
#                     15          86.206897  69.884170  74.137931   4.668988
#                     20          93.103448  72.413793  78.620690   6.038586
# LMA-Hybrid-CHI2     4           89.655172  89.655172  89.655172   0.000000
#                     7           86.206897  86.206897  86.206897   0.000000
#                     10          86.206897  86.206897  86.206897   0.000000
#                     12          79.310345  79.310345  79.310345   0.000000
#                     15          93.103448  93.103448  93.103448   0.000000
#                     20          93.103448  93.103448  93.103448   0.000000
# LMA-Hybrid-MRMR     4           82.758621  82.758621  82.758621   0.000000
#                     7           75.862069  75.862069  75.862069   0.000000
#                     10          72.413793  72.413793  72.413793   0.000000
#                     12          75.862069  75.862069  75.862069   0.000000
#                     15          82.758621  82.758621  82.758621   0.000000
#                     20          75.862069  75.862069  75.862069   0.000000
# LMA-MRMR            4           72.413793  72.413793  72.413793   2.106167
#                     7           75.862069  68.725869  69.655172   9.994053
#                     10          75.862069  66.023166  70.000000   7.971743
#                     12          79.310345  61.389961  70.689655   8.168201
#                     15          75.862069  68.965517  72.758621   7.509407
#                     20          75.862069  72.413793  73.448276   7.075464
# PSO-CHI2            4           89.655172  61.003861  77.586207  11.278632
#                     7           86.206897  65.517241  76.896552  12.762916
#                     10          86.206897  62.068966  75.517241  11.499639
#                     12          86.206897  62.068966  74.827586   9.871134
#                     15          93.103448  68.965517  79.655172   9.979662
#                     20          93.103448  62.068966  77.586207  12.648323
# PSO-MRMR            4           82.758621  72.413793  74.827586  10.512567
#                     7           75.862069  68.965517  72.068966  10.584019
#                     10          75.862069  68.965517  72.068966  12.158513
#                     12          75.862069  68.965517  72.413793   9.761307
#                     15          82.758621  68.965517  73.448276  11.856510
#                     20          75.862069  39.382239  69.310345  12.192264
#
#                                  Mean Time    STD Time  Mean Epochs  \
# OptimizationFeature No. hidden
# LMA-CHI2            4             1.339887    1.207812         25.0
#                     7             1.392871    0.569281         17.0
#                     10            1.797067    0.835483         16.2
#                     12            1.878486    0.552377         16.6
#                     15            2.311570    1.149900         15.1
#                     20            2.664661    0.653258         16.2
# LMA-Hybrid-CHI2     4             2.186616    0.000000         15.0
#                     7             0.479476    0.000000         14.0
#                     10            0.675992    0.000000         21.0
#                     12            0.820640    0.000000         13.0
#                     15            0.999435    0.000000         14.0
#                     20            1.307255    0.000000         17.0
# LMA-Hybrid-MRMR     4             0.422878    0.000000         11.0
#                     7             0.560446    0.000000         14.0
#                     10            0.839983    0.000000         12.0
#                     12            0.510992    0.000000          9.0
#                     15            0.739149    0.000000         10.0
#                     20            0.906983    0.000000          9.0
# LMA-MRMR            4             0.748156    0.225553         15.6
#                     7             0.850657    0.244972         14.2
#                     10            1.019804    0.347522         13.3
#                     12            1.315688    1.368825         14.8
#                     15            1.759400    0.275018         13.5
#                     20            2.729120    1.222894         16.4
# PSO-CHI2            4           292.106288  291.971697         14.3
#                     7           253.886045  296.179029         14.1
#                     10          213.363299  263.315762         16.8
#                     12          267.921206  276.169170         14.5
#                     15          127.295749  249.185440         13.4
#                     20          206.711087  253.526478         16.5
# PSO-MRMR            4           239.935234  245.771593         14.8
#                     7           148.732815  227.610301         13.4
#                     10          142.602351  201.448714         13.1
#                     12          244.655322  253.163853         15.5
#                     15          182.183276  223.855217         11.8
#                     20          151.502212  208.816610         15.9
#
#                                 STD Epochs    Database OptimizationAlgorithm  \
# OptimizationFeature No. hidden
# LMA-CHI2            4            28.343136  white_wine                   LMA
#                     7             4.467164  white_wine                   LMA
#                     10            5.652925  white_wine                   LMA
#                     12            3.806427  white_wine                   LMA
#                     15            3.541814  white_wine                   LMA
#                     20            8.841820  white_wine                   LMA
# LMA-Hybrid-CHI2     4             0.000000  white_wine            LMA-Hybrid
#                     7             0.000000  white_wine            LMA-Hybrid
#                     10            0.000000  white_wine            LMA-Hybrid
#                     12            0.000000  white_wine            LMA-Hybrid
#                     15            0.000000  white_wine            LMA-Hybrid
#                     20            0.000000  white_wine            LMA-Hybrid
# LMA-Hybrid-MRMR     4             0.000000  white_wine            LMA-Hybrid
#                     7             0.000000  white_wine            LMA-Hybrid
#                     10            0.000000  white_wine            LMA-Hybrid
#                     12            0.000000  white_wine            LMA-Hybrid
#                     15            0.000000  white_wine            LMA-Hybrid
#                     20            0.000000  white_wine            LMA-Hybrid
# LMA-MRMR            4             3.400980  white_wine                   LMA
#                     7             3.359894  white_wine                   LMA
#                     10            2.668749  white_wine                   LMA
#                     12            3.675746  white_wine                   LMA
#                     15            5.292552  white_wine                   LMA
#                     20            6.022181  white_wine                   LMA
# PSO-CHI2            4             7.941452  white_wine                   PSO
#                     7             8.582281  white_wine                   PSO
#                     10            9.333929  white_wine                   PSO
#                     12            9.416888  white_wine                   PSO
#                     15            7.863417  white_wine                   PSO
#                     20            8.733079  white_wine                   PSO
# PSO-MRMR            4             7.578478  white_wine                   PSO
#                     7             9.856752  white_wine                   PSO
#                     10            8.978988  white_wine                   PSO
#                     12            8.854377  white_wine                   PSO
#                     15            8.695465  white_wine                   PSO
#                     20            7.809538  white_wine                   PSO
#
#                                FeatureSelectionMethod
# OptimizationFeature No. hidden
# LMA-CHI2            4                            CHI2
#                     7                            CHI2
#                     10                           CHI2
#                     12                           CHI2
#                     15                           CHI2
#                     20                           CHI2
# LMA-Hybrid-CHI2     4                            CHI2
#                     7                            CHI2
#                     10                           CHI2
#                     12                           CHI2
#                     15                           CHI2
#                     20                           CHI2
# LMA-Hybrid-MRMR     4                            MRMR
#                     7                            MRMR
#                     10                           MRMR
#                     12                           MRMR
#                     15                           MRMR
#                     20                           MRMR
# LMA-MRMR            4                            MRMR
#                     7                            MRMR
#                     10                           MRMR
#                     12                           MRMR
#                     15                           MRMR
#                     20                           MRMR
# PSO-CHI2            4                            CHI2
#                     7                            CHI2
#                     10                           CHI2
#                     12                           CHI2
#                     15                           CHI2
#                     20                           CHI2
# PSO-MRMR            4                            MRMR
#                     7                            MRMR
#                     10                           MRMR
#                     12                           MRMR
#                     15                           MRMR
#                     20                           MRMR

# %%
feature = 'Best Acc'
for database in db_names:
    results = pd_results[pd_results['Database']==database][['No. hidden', feature, 'OptimizationFeature']]
    table = pd.pivot_table(results, columns=['OptimizationFeature'], index=['No. hidden'],  aggfunc=np.max)
    table.plot(title=database)

# %% [markdown]
# # Best accuracy

# %%
for database in db_names:   
    display(Markdown('## '+database))
    general_results_algorithm = pd.DataFrame([])
    for algorithm in results['OptimizationFeature'].unique():
        results_algorithm = pd_results[ (pd_results['Database'] == database) & (pd_results['OptimizationFeature'] == algorithm)]
        results_algorithm = results_algorithm.iloc[[results_algorithm['Best Acc'].idxmax()]]
        general_results_algorithm = general_results_algorithm.append(results_algorithm)
    general_results_algorithm.sort_values(by=['Best Acc','No. hidden'], ascending=[False, True], inplace=True)
    display(general_results_algorithm)
# Out:
# ## parkinsons
#    No. hidden   Best Acc  Worst Acc       Mean       STD   Mean Time  \
# 4          15  93.103448  68.965517  79.655172  8.360044  111.386124
# 4          15  93.103448  93.103448  93.103448  0.000000    0.199600
# 5          20  93.103448  72.413793  78.620690  6.038586    0.455432
# 0           4  82.758621  72.413793  74.827586  3.271322  184.455978
# 0           4  82.758621  82.758621  82.758621  0.000000    0.325367
# 3          12  79.310345  48.275862  70.689655  8.168201    0.229099
#
#      STD Time  Mean Epochs  STD Epochs    Database OptimizationAlgorithm  \
# 4  204.882794         13.4    6.686637  parkinsons                   PSO
# 4    0.000000          6.0    0.000000  parkinsons            LMA-Hybrid
# 5    0.134241         12.2    8.841820  parkinsons                   LMA
# 0  207.723843         13.8    5.006662  parkinsons                   PSO
# 0    0.000000          6.0    0.000000  parkinsons            LMA-Hybrid
# 3    0.028714          8.0    2.943920  parkinsons                   LMA
#
#   FeatureSelectionMethod OptimizationFeature
# 4                   CHI2            PSO-CHI2
# 4                   CHI2     LMA-Hybrid-CHI2
# 5                   CHI2            LMA-CHI2
# 0                   MRMR            PSO-MRMR
# 0                   MRMR     LMA-Hybrid-MRMR
# 3                   MRMR            LMA-MRMR
# ## car
#    No. hidden   Best Acc  Worst Acc       Mean       STD   Mean Time  \
# 4          15  76.447876  65.637066  70.270270  3.519896   13.327370
# 1           7  76.061776  72.200772  73.204633  1.154003    0.427171
# 4          15  74.131274  74.131274  74.131274  0.000000    0.356322
# 3          12  69.884170  67.181467  68.725869  0.656244  137.755477
# 2          10  69.111969  69.111969  69.111969  0.000000    0.167710
# 0           4  68.725869  68.725869  68.725869  0.000000    0.275268
#
#      STD Time  Mean Epochs  STD Epochs Database OptimizationAlgorithm  \
# 4    8.246405         11.8    6.972964      car                   PSO
# 1    0.139388         17.0    2.624669      car                   LMA
# 4    0.000000         11.0    0.000000      car            LMA-Hybrid
# 3  208.916819         10.8    8.854377      car                   PSO
# 2    0.000000          6.0    0.000000      car            LMA-Hybrid
# 0    0.225553         11.5    2.635231      car                   LMA
#
#   FeatureSelectionMethod OptimizationFeature
# 4                   CHI2            PSO-CHI2
# 1                   CHI2            LMA-CHI2
# 4                   CHI2     LMA-Hybrid-CHI2
# 3                   MRMR            PSO-MRMR
# 2                   MRMR     LMA-Hybrid-MRMR
# 0                   MRMR            LMA-MRMR
# ## red_wine
#    No. hidden   Best Acc  Worst Acc       Mean        STD   Mean Time  \
# 2          10  62.761506  29.288703  49.121339  11.499639  197.404303
# 5          20  62.761506  55.648536  59.121339   1.753666    1.848995
# 0           4  61.924686  61.924686  61.924686   0.000000    0.266837
# 2          10  52.719665  33.472803  45.104603   5.988447  100.416199
# 2          10  52.719665  52.719665  52.719665   0.000000    0.233077
# 2          10  51.882845  46.443515  48.744770   1.605420    0.826144
#
#      STD Time  Mean Epochs  STD Epochs  Database OptimizationAlgorithm  \
# 2  247.364349         16.8    4.131182  red_wine                   PSO
# 5    0.572443         13.8    2.043961  red_wine                   LMA
# 0    0.000000          8.0    0.000000  red_wine            LMA-Hybrid
# 2  189.177157         12.8    7.699928  red_wine                   PSO
# 2    0.000000          8.0    0.000000  red_wine            LMA-Hybrid
# 2    0.347522         11.7    1.888562  red_wine                   LMA
#
#   FeatureSelectionMethod OptimizationFeature
# 2                   CHI2            PSO-CHI2
# 5                   CHI2            LMA-CHI2
# 0                   CHI2     LMA-Hybrid-CHI2
# 2                   MRMR            PSO-MRMR
# 2                   MRMR     LMA-Hybrid-MRMR
# 2                   MRMR            LMA-MRMR
# ## white_wine
#    No. hidden   Best Acc  Worst Acc       Mean       STD   Mean Time  \
# 0           4  53.133515  18.937330  43.760218  9.655590  235.918138
# 0           4  51.498638  44.959128  46.880109  2.106167    0.748156
# 3          12  50.544959  46.049046  47.534060  1.313770    1.878486
# 4          15  49.455041  49.455041  49.455041  0.000000    0.739149
# 0           4  49.318801  49.318801  49.318801  0.000000    0.484902
# 5          20  48.637602  20.844687  33.038147  8.728389  103.681573
#
#      STD Time  Mean Epochs  STD Epochs    Database OptimizationAlgorithm  \
# 0  291.971697         13.2    6.545567  white_wine                   PSO
# 0    0.100273         15.6    2.913570  white_wine                   LMA
# 3    0.375130         15.0    3.800585  white_wine                   LMA
# 4    0.000000         10.0    0.000000  white_wine            LMA-Hybrid
# 0    0.000000          9.0    0.000000  white_wine            LMA-Hybrid
# 5  208.816610          8.3    7.303728  white_wine                   PSO
#
#   FeatureSelectionMethod OptimizationFeature
# 0                   CHI2            PSO-CHI2
# 0                   MRMR            LMA-MRMR
# 3                   CHI2            LMA-CHI2
# 4                   MRMR     LMA-Hybrid-MRMR
# 0                   CHI2     LMA-Hybrid-CHI2
# 5                   MRMR            PSO-MRMR

# %% [markdown]
# # Mean epochs

# %%
for database in db_names:   
    display(Markdown('## '+database))
    general_results_algorithm = pd.DataFrame([])
    for algorithm in results['OptimizationFeature'].unique():
        results_algorithm = pd_results[ (pd_results['Database'] == database) & (pd_results['OptimizationFeature'] == algorithm)]
        results_algorithm = results_algorithm.iloc[[results_algorithm['Best Acc'].idxmax()]]
        general_results_algorithm = general_results_algorithm.append(results_algorithm)
    general_results_algorithm.sort_values(by=['Mean Epochs','No. hidden'], ascending=[True, True], inplace=True)
    display(general_results_algorithm)
# Out:
# ## parkinsons
#    No. hidden   Best Acc  Worst Acc       Mean       STD   Mean Time  \
# 0           4  82.758621  82.758621  82.758621  0.000000    0.325367
# 4          15  93.103448  93.103448  93.103448  0.000000    0.199600
# 3          12  79.310345  48.275862  70.689655  8.168201    0.229099
# 5          20  93.103448  72.413793  78.620690  6.038586    0.455432
# 4          15  93.103448  68.965517  79.655172  8.360044  111.386124
# 0           4  82.758621  72.413793  74.827586  3.271322  184.455978
#
#      STD Time  Mean Epochs  STD Epochs    Database OptimizationAlgorithm  \
# 0    0.000000          6.0    0.000000  parkinsons            LMA-Hybrid
# 4    0.000000          6.0    0.000000  parkinsons            LMA-Hybrid
# 3    0.028714          8.0    2.943920  parkinsons                   LMA
# 5    0.134241         12.2    8.841820  parkinsons                   LMA
# 4  204.882794         13.4    6.686637  parkinsons                   PSO
# 0  207.723843         13.8    5.006662  parkinsons                   PSO
#
#   FeatureSelectionMethod OptimizationFeature
# 0                   MRMR     LMA-Hybrid-MRMR
# 4                   CHI2     LMA-Hybrid-CHI2
# 3                   MRMR            LMA-MRMR
# 5                   CHI2            LMA-CHI2
# 4                   CHI2            PSO-CHI2
# 0                   MRMR            PSO-MRMR
# ## car
#    No. hidden   Best Acc  Worst Acc       Mean       STD   Mean Time  \
# 2          10  69.111969  69.111969  69.111969  0.000000    0.167710
# 3          12  69.884170  67.181467  68.725869  0.656244  137.755477
# 4          15  74.131274  74.131274  74.131274  0.000000    0.356322
# 0           4  68.725869  68.725869  68.725869  0.000000    0.275268
# 4          15  76.447876  65.637066  70.270270  3.519896   13.327370
# 1           7  76.061776  72.200772  73.204633  1.154003    0.427171
#
#      STD Time  Mean Epochs  STD Epochs Database OptimizationAlgorithm  \
# 2    0.000000          6.0    0.000000      car            LMA-Hybrid
# 3  208.916819         10.8    8.854377      car                   PSO
# 4    0.000000         11.0    0.000000      car            LMA-Hybrid
# 0    0.225553         11.5    2.635231      car                   LMA
# 4    8.246405         11.8    6.972964      car                   PSO
# 1    0.139388         17.0    2.624669      car                   LMA
#
#   FeatureSelectionMethod OptimizationFeature
# 2                   MRMR     LMA-Hybrid-MRMR
# 3                   MRMR            PSO-MRMR
# 4                   CHI2     LMA-Hybrid-CHI2
# 0                   MRMR            LMA-MRMR
# 4                   CHI2            PSO-CHI2
# 1                   CHI2            LMA-CHI2
# ## red_wine
#    No. hidden   Best Acc  Worst Acc       Mean        STD   Mean Time  \
# 0           4  61.924686  61.924686  61.924686   0.000000    0.266837
# 2          10  52.719665  52.719665  52.719665   0.000000    0.233077
# 2          10  51.882845  46.443515  48.744770   1.605420    0.826144
# 2          10  52.719665  33.472803  45.104603   5.988447  100.416199
# 5          20  62.761506  55.648536  59.121339   1.753666    1.848995
# 2          10  62.761506  29.288703  49.121339  11.499639  197.404303
#
#      STD Time  Mean Epochs  STD Epochs  Database OptimizationAlgorithm  \
# 0    0.000000          8.0    0.000000  red_wine            LMA-Hybrid
# 2    0.000000          8.0    0.000000  red_wine            LMA-Hybrid
# 2    0.347522         11.7    1.888562  red_wine                   LMA
# 2  189.177157         12.8    7.699928  red_wine                   PSO
# 5    0.572443         13.8    2.043961  red_wine                   LMA
# 2  247.364349         16.8    4.131182  red_wine                   PSO
#
#   FeatureSelectionMethod OptimizationFeature
# 0                   CHI2     LMA-Hybrid-CHI2
# 2                   MRMR     LMA-Hybrid-MRMR
# 2                   MRMR            LMA-MRMR
# 2                   MRMR            PSO-MRMR
# 5                   CHI2            LMA-CHI2
# 2                   CHI2            PSO-CHI2
# ## white_wine
#    No. hidden   Best Acc  Worst Acc       Mean       STD   Mean Time  \
# 5          20  48.637602  20.844687  33.038147  8.728389  103.681573
# 0           4  49.318801  49.318801  49.318801  0.000000    0.484902
# 4          15  49.455041  49.455041  49.455041  0.000000    0.739149
# 0           4  53.133515  18.937330  43.760218  9.655590  235.918138
# 3          12  50.544959  46.049046  47.534060  1.313770    1.878486
# 0           4  51.498638  44.959128  46.880109  2.106167    0.748156
#
#      STD Time  Mean Epochs  STD Epochs    Database OptimizationAlgorithm  \
# 5  208.816610          8.3    7.303728  white_wine                   PSO
# 0    0.000000          9.0    0.000000  white_wine            LMA-Hybrid
# 4    0.000000         10.0    0.000000  white_wine            LMA-Hybrid
# 0  291.971697         13.2    6.545567  white_wine                   PSO
# 3    0.375130         15.0    3.800585  white_wine                   LMA
# 0    0.100273         15.6    2.913570  white_wine                   LMA
#
#   FeatureSelectionMethod OptimizationFeature
# 5                   MRMR            PSO-MRMR
# 0                   CHI2     LMA-Hybrid-CHI2
# 4                   MRMR     LMA-Hybrid-MRMR
# 0                   CHI2            PSO-CHI2
# 3                   CHI2            LMA-CHI2
# 0                   MRMR            LMA-MRMR

# %% [markdown]
# # Mean Execution Time

# %%
for database in db_names:   
    display(Markdown('## '+database))
    general_results_algorithm = pd.DataFrame([])
    for algorithm in results['OptimizationFeature'].unique():
        results_algorithm = pd_results[ (pd_results['Database'] == database) & (pd_results['OptimizationFeature'] == algorithm)]
        results_algorithm = results_algorithm.iloc[[results_algorithm['Best Acc'].idxmax()]]
        general_results_algorithm = general_results_algorithm.append(results_algorithm)
    general_results_algorithm.sort_values(by=['Mean Time','No. hidden'], ascending=[True, True], inplace=True)
    display(general_results_algorithm)
# Out:
# ## parkinsons
#    No. hidden   Best Acc  Worst Acc       Mean       STD   Mean Time  \
# 4          15  93.103448  93.103448  93.103448  0.000000    0.199600
# 3          12  79.310345  48.275862  70.689655  8.168201    0.229099
# 0           4  82.758621  82.758621  82.758621  0.000000    0.325367
# 5          20  93.103448  72.413793  78.620690  6.038586    0.455432
# 4          15  93.103448  68.965517  79.655172  8.360044  111.386124
# 0           4  82.758621  72.413793  74.827586  3.271322  184.455978
#
#      STD Time  Mean Epochs  STD Epochs    Database OptimizationAlgorithm  \
# 4    0.000000          6.0    0.000000  parkinsons            LMA-Hybrid
# 3    0.028714          8.0    2.943920  parkinsons                   LMA
# 0    0.000000          6.0    0.000000  parkinsons            LMA-Hybrid
# 5    0.134241         12.2    8.841820  parkinsons                   LMA
# 4  204.882794         13.4    6.686637  parkinsons                   PSO
# 0  207.723843         13.8    5.006662  parkinsons                   PSO
#
#   FeatureSelectionMethod OptimizationFeature
# 4                   CHI2     LMA-Hybrid-CHI2
# 3                   MRMR            LMA-MRMR
# 0                   MRMR     LMA-Hybrid-MRMR
# 5                   CHI2            LMA-CHI2
# 4                   CHI2            PSO-CHI2
# 0                   MRMR            PSO-MRMR
# ## car
#    No. hidden   Best Acc  Worst Acc       Mean       STD   Mean Time  \
# 2          10  69.111969  69.111969  69.111969  0.000000    0.167710
# 0           4  68.725869  68.725869  68.725869  0.000000    0.275268
# 4          15  74.131274  74.131274  74.131274  0.000000    0.356322
# 1           7  76.061776  72.200772  73.204633  1.154003    0.427171
# 4          15  76.447876  65.637066  70.270270  3.519896   13.327370
# 3          12  69.884170  67.181467  68.725869  0.656244  137.755477
#
#      STD Time  Mean Epochs  STD Epochs Database OptimizationAlgorithm  \
# 2    0.000000          6.0    0.000000      car            LMA-Hybrid
# 0    0.225553         11.5    2.635231      car                   LMA
# 4    0.000000         11.0    0.000000      car            LMA-Hybrid
# 1    0.139388         17.0    2.624669      car                   LMA
# 4    8.246405         11.8    6.972964      car                   PSO
# 3  208.916819         10.8    8.854377      car                   PSO
#
#   FeatureSelectionMethod OptimizationFeature
# 2                   MRMR     LMA-Hybrid-MRMR
# 0                   MRMR            LMA-MRMR
# 4                   CHI2     LMA-Hybrid-CHI2
# 1                   CHI2            LMA-CHI2
# 4                   CHI2            PSO-CHI2
# 3                   MRMR            PSO-MRMR
# ## red_wine
#    No. hidden   Best Acc  Worst Acc       Mean        STD   Mean Time  \
# 2          10  52.719665  52.719665  52.719665   0.000000    0.233077
# 0           4  61.924686  61.924686  61.924686   0.000000    0.266837
# 2          10  51.882845  46.443515  48.744770   1.605420    0.826144
# 5          20  62.761506  55.648536  59.121339   1.753666    1.848995
# 2          10  52.719665  33.472803  45.104603   5.988447  100.416199
# 2          10  62.761506  29.288703  49.121339  11.499639  197.404303
#
#      STD Time  Mean Epochs  STD Epochs  Database OptimizationAlgorithm  \
# 2    0.000000          8.0    0.000000  red_wine            LMA-Hybrid
# 0    0.000000          8.0    0.000000  red_wine            LMA-Hybrid
# 2    0.347522         11.7    1.888562  red_wine                   LMA
# 5    0.572443         13.8    2.043961  red_wine                   LMA
# 2  189.177157         12.8    7.699928  red_wine                   PSO
# 2  247.364349         16.8    4.131182  red_wine                   PSO
#
#   FeatureSelectionMethod OptimizationFeature
# 2                   MRMR     LMA-Hybrid-MRMR
# 0                   CHI2     LMA-Hybrid-CHI2
# 2                   MRMR            LMA-MRMR
# 5                   CHI2            LMA-CHI2
# 2                   MRMR            PSO-MRMR
# 2                   CHI2            PSO-CHI2
# ## white_wine
#    No. hidden   Best Acc  Worst Acc       Mean       STD   Mean Time  \
# 0           4  49.318801  49.318801  49.318801  0.000000    0.484902
# 4          15  49.455041  49.455041  49.455041  0.000000    0.739149
# 0           4  51.498638  44.959128  46.880109  2.106167    0.748156
# 3          12  50.544959  46.049046  47.534060  1.313770    1.878486
# 5          20  48.637602  20.844687  33.038147  8.728389  103.681573
# 0           4  53.133515  18.937330  43.760218  9.655590  235.918138
#
#      STD Time  Mean Epochs  STD Epochs    Database OptimizationAlgorithm  \
# 0    0.000000          9.0    0.000000  white_wine            LMA-Hybrid
# 4    0.000000         10.0    0.000000  white_wine            LMA-Hybrid
# 0    0.100273         15.6    2.913570  white_wine                   LMA
# 3    0.375130         15.0    3.800585  white_wine                   LMA
# 5  208.816610          8.3    7.303728  white_wine                   PSO
# 0  291.971697         13.2    6.545567  white_wine                   PSO
#
#   FeatureSelectionMethod OptimizationFeature
# 0                   CHI2     LMA-Hybrid-CHI2
# 4                   MRMR     LMA-Hybrid-MRMR
# 0                   MRMR            LMA-MRMR
# 3                   CHI2            LMA-CHI2
# 5                   MRMR            PSO-MRMR
# 0                   CHI2            PSO-CHI2

# %%
for database in db_names:

    results_algorithm = pd.DataFrame([], columns=['Algorithm', 'Best', 'Worst', 'Mean'])

    for algorithm in pd_results['OptimizationFeature'].unique():

        results_algorithm_aux = pd_results[ (pd_results['Database'] == database) & (pd_results['OptimizationFeature'] == algorithm)]

        best  = np.max(results_algorithm_aux['Best Acc']) 
        worst = np.min(results_algorithm_aux['Worst Acc'])
        mean  = np.mean(results_algorithm_aux['Mean'])
        new_line = {'Algorithm':algorithm, 'Best':best, 'Worst':worst, 'Mean':mean}
        results_algorithm = results_algorithm.append(new_line, ignore_index=True)

    results_algorithm.set_index('Algorithm', inplace=True)
    results_algorithm.plot.bar(title=database)
